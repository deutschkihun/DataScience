# %% [markdown]
# <a href="https://colab.research.google.com/github/deutschkihun/DataScience/blob/master/Starbucks_StockPricePrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Stock price prediction**
#
# ## **Source file folder**
# - [Google drive](https://drive.google.com/drive/folders/1fiPVMkS4VoQtOzlhIU16__lklyIbMLiU?usp=sharing)
#
# ## **Reference**
# - [Github](https://github.com/kairess/stock_crypto_price_prediction/blob/master/stock_samsung.ipynb)
# - [Yahoo finance](https://finance.yahoo.com/)

# %% [markdown]
# ## 1.Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense,GRU
from keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf

# %% [markdown]
# ## 2.Reading datasets

# %%
starbucks = pd.read_csv('/content/drive/My Drive/Colab Notebooks/ML DL/Projects/stock price prediction/starbucks.csv')

# %% [markdown]
# ## 3.Data Visualization

# %%
starbucks_copy =  pd.read_csv('/content/drive/My Drive/Colab Notebooks/ML DL/Projects/stock price prediction/starbucks.csv',
                      index_col='Date', parse_dates=['Date'])

starbucks_copy["High"][:'2019'].plot(figsize=(16,6),legend=True)
starbucks_copy["High"]['2020':].plot(figsize=(16,6),legend=True)
plt.legend(['Train','Test'])
plt.title('starbucks stock price',fontsize=20)
plt.xlabel('year')
plt.ylabel('stock price');

# %% [markdown]
# ## 4. Data preprocessing

# %% [markdown]
# ### 4.1 Define middle price

# %%
high_prices = starbucks['High'].values
low_prices = starbucks['Low'].values
mid_prices = (high_prices + low_prices) / 2

# %% [markdown]
# ## 4.2 Create window

# %%
seq_len = 50
sequence_length = seq_len + 1

result = []
for index in range(len(mid_prices) - sequence_length):
    result.append(mid_prices[index: index + sequence_length])

# %% [markdown]
# ## 4.3 Normalization

# %%
# Normalization by ussig MinMaxscaler 

sc = MinMaxScaler(feature_range=(0,1))
result = sc.fit_transform(result)

# %% [markdown]
# ## 4.4 Split train,validation and test data

# %%
row = int(round(result.shape[0] * 0.8))
train = result[:row, :]

# %%
# split train and test data
row = int(round(result.shape[0] * 0.8))
train = result[:row, :]
np.random.shuffle(train)

x_train = train[:, :-1]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = train[:, -1]

x_test = result[row:, :-1]
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
y_test = result[row:, -1]

x_train.shape, x_test.shape
# Out:
# ((966, 50, 1), (242, 50, 1))

# %% [markdown]
# ## 5.1 Modeling Option 1: LSTM

# %%
def solution_model():

  model = Sequential()
  model.add(LSTM(50,return_sequences=True))
  model.add(LSTM(64,return_sequences=False))
  model.add(Dense(20,activation='relu'))
  model.add(Dense(10,activation='relu'))
  model.add(Dense(1,activation='linear'))


  model.compile(loss='mse',optimizer='rmsprop',metrics=['accuracy'])

  checkpoint_path = 'stockprice_checkpoint.ckpt'
  checkpoint = ModelCheckpoint(checkpoint_path,
                               save_weights_only=True, 
                               save_best_only=True, 
                               monitor='val_loss',
                                verbose=1)

  model.fit(x_train,y_train,
            callbacks=[checkpoint],
            validation_data=(x_test,y_test),          
            batch_size=15,
             verbose=2,
            epochs=30)
  model.load_weights(checkpoint_path)

  return model

# %% [markdown]
# ## 6.Training

# %%
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Train on 966 samples, validate on 242 samples
# Epoch 1/30
#  - 4s - loss: 0.0075 - accuracy: 0.0010 - val_loss: 0.0527 - val_accuracy: 0.0041
#
# Epoch 00001: val_loss improved from inf to 0.05266, saving model to stockprice_checkpoint.ckpt
# Epoch 2/30
#  - 3s - loss: 0.0021 - accuracy: 0.0010 - val_loss: 0.0077 - val_accuracy: 0.0041
#
# Epoch 00002: val_loss improved from 0.05266 to 0.00773, saving model to stockprice_checkpoint.ckpt
# Epoch 3/30
#  - 3s - loss: 0.0016 - accuracy: 0.0010 - val_loss: 0.0050 - val_accuracy: 0.0041
#
# Epoch 00003: val_loss improved from 0.00773 to 0.00497, saving model to stockprice_checkpoint.ckpt
# Epoch 4/30
#  - 3s - loss: 0.0014 - accuracy: 0.0010 - val_loss: 0.0196 - val_accuracy: 0.0041
#
# Epoch 00004: val_loss did not improve from 0.00497
# Epoch 5/30
#  - 3s - loss: 0.0011 - accuracy: 0.0010 - val_loss: 0.0037 - val_accuracy: 0.0041
#
# Epoch 00005: val_loss improved from 0.00497 to 0.00367, saving model to stockprice_checkpoint.ckpt
# Epoch 6/30
#  - 3s - loss: 0.0011 - accuracy: 0.0010 - val_loss: 0.0094 - val_accuracy: 0.0041
#
# Epoch 00006: val_loss did not improve from 0.00367
# Epoch 7/30
#  - 3s - loss: 8.9017e-04 - accuracy: 0.0010 - val_loss: 0.0097 - val_accuracy: 0.0041
#
# Epoch 00007: val_loss did not improve from 0.00367
# Epoch 8/30
#  - 3s - loss: 8.3233e-04 - accuracy: 0.0010 - val_loss: 0.0045 - val_accuracy: 0.0041
#
# Epoch 00008: val_loss did not improve from 0.00367
# Epoch 9/30
#  - 3s - loss: 6.7688e-04 - accuracy: 0.0010 - val_loss: 0.0031 - val_accuracy: 0.0041
#
# Epoch 00009: val_loss improved from 0.00367 to 0.00311, saving model to stockprice_checkpoint.ckpt
# Epoch 10/30
#  - 3s - loss: 6.8197e-04 - accuracy: 0.0010 - val_loss: 0.0064 - val_accuracy: 0.0041
#
# Epoch 00010: val_loss did not improve from 0.00311
# Epoch 11/30
#  - 3s - loss: 5.8882e-04 - accuracy: 0.0010 - val_loss: 0.0028 - val_accuracy: 0.0041
#
# Epoch 00011: val_loss improved from 0.00311 to 0.00277, saving model to stockprice_checkpoint.ckpt
# Epoch 12/30
#  - 3s - loss: 5.8409e-04 - accuracy: 0.0010 - val_loss: 0.0019 - val_accuracy: 0.0041
#
# Epoch 00012: val_loss improved from 0.00277 to 0.00195, saving model to stockprice_checkpoint.ckpt
# Epoch 13/30
#  - 3s - loss: 4.7242e-04 - accuracy: 0.0010 - val_loss: 0.0141 - val_accuracy: 0.0041
#
# Epoch 00013: val_loss did not improve from 0.00195
# Epoch 14/30
#  - 3s - loss: 5.1410e-04 - accuracy: 0.0010 - val_loss: 0.0017 - val_accuracy: 0.0041
#
# Epoch 00014: val_loss improved from 0.00195 to 0.00165, saving model to stockprice_checkpoint.ckpt
# Epoch 15/30
#  - 3s - loss: 4.9041e-04 - accuracy: 0.0010 - val_loss: 0.0039 - val_accuracy: 0.0041
#
# Epoch 00015: val_loss did not improve from 0.00165
# Epoch 16/30
#  - 3s - loss: 4.3656e-04 - accuracy: 0.0010 - val_loss: 0.0014 - val_accuracy: 0.0041
#
# Epoch 00016: val_loss improved from 0.00165 to 0.00135, saving model to stockprice_checkpoint.ckpt
# Epoch 17/30
#  - 3s - loss: 3.9660e-04 - accuracy: 0.0010 - val_loss: 0.0018 - val_accuracy: 0.0041
#
# Epoch 00017: val_loss did not improve from 0.00135
# Epoch 18/30
#  - 3s - loss: 4.0013e-04 - accuracy: 0.0010 - val_loss: 0.0017 - val_accuracy: 0.0041
#
# Epoch 00018: val_loss did not improve from 0.00135
# Epoch 19/30
#  - 3s - loss: 3.8308e-04 - accuracy: 0.0010 - val_loss: 0.0024 - val_accuracy: 0.0041
#
# Epoch 00019: val_loss did not improve from 0.00135
# Epoch 20/30
#  - 3s - loss: 3.8941e-04 - accuracy: 0.0010 - val_loss: 0.0012 - val_accuracy: 0.0041
#
# Epoch 00020: val_loss improved from 0.00135 to 0.00124, saving model to stockprice_checkpoint.ckpt
# Epoch 21/30
#  - 3s - loss: 3.5177e-04 - accuracy: 0.0010 - val_loss: 0.0014 - val_accuracy: 0.0041
#
# Epoch 00021: val_loss did not improve from 0.00124
# Epoch 22/30
#  - 3s - loss: 3.4612e-04 - accuracy: 0.0010 - val_loss: 0.0016 - val_accuracy: 0.0041
#
# Epoch 00022: val_loss did not improve from 0.00124
# Epoch 23/30
#  - 3s - loss: 3.2411e-04 - accuracy: 0.0010 - val_loss: 0.0070 - val_accuracy: 0.0041
#
# Epoch 00023: val_loss did not improve from 0.00124
# Epoch 24/30
#  - 3s - loss: 3.3901e-04 - accuracy: 0.0010 - val_loss: 0.0111 - val_accuracy: 0.0041
#
# Epoch 00024: val_loss did not improve from 0.00124
# Epoch 25/30
#  - 3s - loss: 3.5858e-04 - accuracy: 0.0010 - val_loss: 0.0015 - val_accuracy: 0.0041
#
# Epoch 00025: val_loss did not improve from 0.00124
# Epoch 26/30
#  - 3s - loss: 3.0598e-04 - accuracy: 0.0010 - val_loss: 0.0084 - val_accuracy: 0.0041
#
# Epoch 00026: val_loss did not improve from 0.00124
# Epoch 27/30
#  - 3s - loss: 3.1076e-04 - accuracy: 0.0010 - val_loss: 0.0014 - val_accuracy: 0.0041
#
# Epoch 00027: val_loss did not improve from 0.00124
# Epoch 28/30
#  - 3s - loss: 3.1276e-04 - accuracy: 0.0010 - val_loss: 0.0018 - val_accuracy: 0.0041
#
# Epoch 00028: val_loss did not improve from 0.00124
# Epoch 29/30
#  - 3s - loss: 2.9959e-04 - accuracy: 0.0010 - val_loss: 0.0017 - val_accuracy: 0.0041
#
# Epoch 00029: val_loss did not improve from 0.00124
# Epoch 30/30
#  - 3s - loss: 3.2081e-04 - accuracy: 0.0010 - val_loss: 0.0021 - val_accuracy: 0.0041
#
# Epoch 00030: val_loss did not improve from 0.00124

# %%
pred = model.predict(x_test)

fig = plt.figure(facecolor='white', figsize=(20, 10))
ax = fig.add_subplot(111)
ax.plot(y_test, label='True')
ax.plot(pred, label='Prediction')
ax.legend(['Real stock graph','Prediction graph'],title='Line Information')
plt.title('Starbucks stock price prediction',fontsize=20);

# %% [markdown]
# ## 5.2 Modelling Option 2: GRU

# %%
def solution_model():

  model = Sequential()
  model.add(GRU(50,return_sequences=True))
  model.add(GRU(64,return_sequences=False))
  model.add(Dense(20,activation='relu'))
  model.add(Dense(10,activation='relu'))
  model.add(Dense(1,activation='linear'))


  model.compile(loss='mse',optimizer='rmsprop',metrics=['accuracy'])

  checkpoint_path = 'stockprice_checkpoint.ckpt'
  checkpoint = ModelCheckpoint(checkpoint_path,
                               save_weights_only=True, 
                               save_best_only=True, 
                               monitor='val_loss',
                                verbose=1)

  model.fit(x_train,y_train,
            callbacks=[checkpoint],
            validation_data=(x_test,y_test),          
            batch_size=15,
             verbose=2,
            epochs=30)
  model.load_weights(checkpoint_path)

  return model

# %%
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Train on 966 samples, validate on 242 samples
# Epoch 1/30
#  - 5s - loss: 0.0055 - accuracy: 0.0010 - val_loss: 0.0129 - val_accuracy: 0.0041
#
# Epoch 00001: val_loss improved from inf to 0.01286, saving model to stockprice_checkpoint.ckpt
# Epoch 2/30
#  - 4s - loss: 0.0010 - accuracy: 0.0010 - val_loss: 0.0031 - val_accuracy: 0.0041
#
# Epoch 00002: val_loss improved from 0.01286 to 0.00310, saving model to stockprice_checkpoint.ckpt
# Epoch 3/30
#  - 4s - loss: 8.5092e-04 - accuracy: 0.0010 - val_loss: 0.0027 - val_accuracy: 0.0041
#
# Epoch 00003: val_loss improved from 0.00310 to 0.00271, saving model to stockprice_checkpoint.ckpt
# Epoch 4/30
#  - 4s - loss: 8.1584e-04 - accuracy: 0.0010 - val_loss: 0.0024 - val_accuracy: 0.0041
#
# Epoch 00004: val_loss improved from 0.00271 to 0.00238, saving model to stockprice_checkpoint.ckpt
# Epoch 5/30
#  - 4s - loss: 6.3340e-04 - accuracy: 0.0010 - val_loss: 0.0033 - val_accuracy: 0.0041
#
# Epoch 00005: val_loss did not improve from 0.00238
# Epoch 6/30
#  - 4s - loss: 5.3914e-04 - accuracy: 0.0010 - val_loss: 0.0142 - val_accuracy: 0.0041
#
# Epoch 00006: val_loss did not improve from 0.00238
# Epoch 7/30
#  - 4s - loss: 5.4706e-04 - accuracy: 0.0010 - val_loss: 0.0025 - val_accuracy: 0.0041
#
# Epoch 00007: val_loss did not improve from 0.00238
# Epoch 8/30
#  - 4s - loss: 5.0347e-04 - accuracy: 0.0010 - val_loss: 0.0014 - val_accuracy: 0.0041
#
# Epoch 00008: val_loss improved from 0.00238 to 0.00136, saving model to stockprice_checkpoint.ckpt
# Epoch 9/30
#  - 4s - loss: 4.4351e-04 - accuracy: 0.0010 - val_loss: 0.0020 - val_accuracy: 0.0041
#
# Epoch 00009: val_loss did not improve from 0.00136
# Epoch 10/30
#  - 4s - loss: 4.2558e-04 - accuracy: 0.0010 - val_loss: 0.0044 - val_accuracy: 0.0041
#
# Epoch 00010: val_loss did not improve from 0.00136
# Epoch 11/30
#  - 4s - loss: 3.9093e-04 - accuracy: 0.0010 - val_loss: 0.0012 - val_accuracy: 0.0041
#
# Epoch 00011: val_loss improved from 0.00136 to 0.00120, saving model to stockprice_checkpoint.ckpt
# Epoch 12/30
#  - 4s - loss: 3.8038e-04 - accuracy: 0.0010 - val_loss: 0.0015 - val_accuracy: 0.0041
#
# Epoch 00012: val_loss did not improve from 0.00120
# Epoch 13/30
#  - 4s - loss: 4.0101e-04 - accuracy: 0.0010 - val_loss: 0.0012 - val_accuracy: 0.0041
#
# Epoch 00013: val_loss improved from 0.00120 to 0.00118, saving model to stockprice_checkpoint.ckpt
# Epoch 14/30
#  - 4s - loss: 3.4471e-04 - accuracy: 0.0010 - val_loss: 0.0013 - val_accuracy: 0.0041
#
# Epoch 00014: val_loss did not improve from 0.00118
# Epoch 15/30
#  - 4s - loss: 3.4428e-04 - accuracy: 0.0010 - val_loss: 0.0031 - val_accuracy: 0.0041
#
# Epoch 00015: val_loss did not improve from 0.00118
# Epoch 16/30
#  - 4s - loss: 3.2711e-04 - accuracy: 0.0010 - val_loss: 0.0022 - val_accuracy: 0.0041
#
# Epoch 00016: val_loss did not improve from 0.00118
# Epoch 17/30
#  - 4s - loss: 3.4796e-04 - accuracy: 0.0010 - val_loss: 0.0017 - val_accuracy: 0.0041
#
# Epoch 00017: val_loss did not improve from 0.00118
# Epoch 18/30
#  - 4s - loss: 3.2375e-04 - accuracy: 0.0010 - val_loss: 0.0014 - val_accuracy: 0.0041
#
# Epoch 00018: val_loss did not improve from 0.00118
# Epoch 19/30
#  - 4s - loss: 3.3919e-04 - accuracy: 0.0010 - val_loss: 0.0021 - val_accuracy: 0.0041
#
# Epoch 00019: val_loss did not improve from 0.00118
# Epoch 20/30
#  - 4s - loss: 3.0870e-04 - accuracy: 0.0010 - val_loss: 0.0014 - val_accuracy: 0.0041
#
# Epoch 00020: val_loss did not improve from 0.00118
# Epoch 21/30
#  - 4s - loss: 3.1194e-04 - accuracy: 0.0010 - val_loss: 0.0014 - val_accuracy: 0.0041
#
# Epoch 00021: val_loss did not improve from 0.00118
# Epoch 22/30
#  - 4s - loss: 3.0796e-04 - accuracy: 0.0010 - val_loss: 0.0018 - val_accuracy: 0.0041
#
# Epoch 00022: val_loss did not improve from 0.00118
# Epoch 23/30
#  - 4s - loss: 3.2897e-04 - accuracy: 0.0010 - val_loss: 0.0012 - val_accuracy: 0.0041
#
# Epoch 00023: val_loss did not improve from 0.00118
# Epoch 24/30
#  - 4s - loss: 2.9318e-04 - accuracy: 0.0010 - val_loss: 0.0017 - val_accuracy: 0.0041
#
# Epoch 00024: val_loss did not improve from 0.00118
# Epoch 25/30
#  - 4s - loss: 3.2295e-04 - accuracy: 0.0010 - val_loss: 0.0016 - val_accuracy: 0.0041
#
# Epoch 00025: val_loss did not improve from 0.00118
# Epoch 26/30
#  - 4s - loss: 2.7397e-04 - accuracy: 0.0010 - val_loss: 0.0089 - val_accuracy: 0.0041
#
# Epoch 00026: val_loss did not improve from 0.00118
# Epoch 27/30
#  - 4s - loss: 3.0465e-04 - accuracy: 0.0010 - val_loss: 0.0013 - val_accuracy: 0.0041
#
# Epoch 00027: val_loss did not improve from 0.00118
# Epoch 28/30
#  - 4s - loss: 2.9625e-04 - accuracy: 0.0010 - val_loss: 0.0056 - val_accuracy: 0.0041
#
# Epoch 00028: val_loss did not improve from 0.00118
# Epoch 29/30
#  - 4s - loss: 2.8814e-04 - accuracy: 0.0010 - val_loss: 0.0014 - val_accuracy: 0.0041
#
# Epoch 00029: val_loss did not improve from 0.00118
# Epoch 30/30
#  - 4s - loss: 2.8718e-04 - accuracy: 0.0010 - val_loss: 0.0014 - val_accuracy: 0.0041
#
# Epoch 00030: val_loss did not improve from 0.00118

# %%
pred = model.predict(x_test)

fig = plt.figure(facecolor='white', figsize=(20, 10))
ax = fig.add_subplot(111)
ax.plot(y_test, label='True')
ax.plot(pred, label='Prediction')
ax.legend(['Real stock graph','Prediction graph'],title='Line Information')
plt.title('Starbucks stock price prediction',fontsize=20);
